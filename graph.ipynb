# %%
import matplotlib.pyplot as plt

# Data for the bar chart
clusters = ['10-layer', '20-layer']
bar_labels = ['8x4 A100 + 8x4 V100', '16x4 A100 + 16x4 V100']
metis_values = [55 + 557, 10423 + 47655]
ours_values = [29 + 533, 1110 + 40098]

# Bar positions
x = range(len(clusters))
width = 0.35  # width of the bars

# Plotting the bar chart
fig, ax = plt.subplots()

# Adding bars for Metis and Ours
metis_bars = ax.bar([pos - width / 2 for pos in x], metis_values, width, label='Metis')
ours_bars = ax.bar([pos + width / 2 for pos in x], ours_values, width, label='Ours')

# Adding labels and title
ax.set_xlabel('Cluster & Model')
ax.set_ylabel('Number of Search Steps')
ax.set_title('Search Steps Comparison')
ax.set_xticks(x)
ax.set_xticklabels([f"{cluster}\n{label}" for cluster, label in zip(clusters, bar_labels)])
ax.legend()

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Adjusting the y-axis for better visibility
fig, ax = plt.subplots()

# Adding bars for Metis and Ours
metis_bars = ax.bar([pos - width / 2 for pos in x], metis_values, width, label='Metis')
ours_bars = ax.bar([pos + width / 2 for pos in x], ours_values, width, label='Ours')

# Adding labels and title
ax.set_xlabel('Cluster & Model')
ax.set_ylabel('Number of Search Steps')
ax.set_xticks(x)
ax.set_xticklabels([f"{cluster}\n{label}" for cluster, label in zip(clusters, bar_labels)])
ax.legend()

# Setting a logarithmic scale for better visibility
ax.set_yscale('log')

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
clusters = ['10-layer', '20-layer']
bar_labels = ['8x4 A100 + 8x4 V100', '16x4 A100 + 16x4 V100']
metis_values = [55 + 557, 10423 + 47655]
ours_values = [29 + 533, 1110 + 40098]

# Bar positions
x = range(len(clusters))
width = 0.35  # width of the bars

# Plotting the bar chart
fig, ax = plt.subplots()

# Adding bars for Metis and Ours
metis_bars = ax.bar([pos - width / 2 for pos in x], metis_values, width, label='Metis')
ours_bars = ax.bar([pos + width / 2 for pos in x], ours_values, width, label='Ours')

# Adding labels and title
ax.set_xlabel('Cluster & Model')
ax.set_ylabel('Number of Search Steps')
ax.set_title('Search Steps Comparison')
ax.set_xticks(x)
ax.set_xticklabels([f"{cluster}\n{label}" for cluster, label in zip(clusters, bar_labels)])
ax.legend()

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Adjusting the y-axis for better visibility
fig, ax = plt.subplots()

# Adding bars for Metis and Ours
metis_bars = ax.bar([pos - width / 2 for pos in x], metis_values, width, label='Metis')
ours_bars = ax.bar([pos + width / 2 for pos in x], ours_values, width, label='Ours')

# Adding labels and title
ax.set_xlabel('Cluster & Model')
ax.set_ylabel('Number of Search Steps')
ax.set_xticks(x)
ax.set_xticklabels([f"{cluster}\n{label}" for cluster, label in zip(clusters, bar_labels)])
ax.legend()

# Setting a logarithmic scale for better visibility
ax.set_yscale('log')

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# -----------------------------------------------------------
# | Number of Layers | Number of GPUs | Metis (ms) | Ours (ms) | Speedup |
# |-|-|-|-|-|
# | 10| 32 | 95.34 | 87.34 | 1.092x |
# | 20 | 64 | 17119.40 | 8498.32 | 2.014x |
# -----------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------
# | Number of Layers | Number of GPUs | Metis | Ours | Reduction |
# |-|-|-|-|-|
# | 10| 32 | 612 | 562 | 8.17% |
# | 20 | 64 | 58078 | 41208 | 29.05% |
# -----------------------------------------------------------
